# %% [markdown]
# <a href="https://colab.research.google.com/github/Y-PradeepKumar/Data-Science/blob/main/Pandas_Data_Frame_creation_%26_index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 style = "color : Brown"> Data Frame </h2>

# %%
# All imports
import numpy as np
import pandas as pd

# %% [markdown]
# <h4 style = "color : Sky blue"> Example - 1</h4>
#
# ##### Create a Data Frame cars using raw data stored in a dictionary

# %%
cars_per_cap = [809, 731, 588, 18, 200, 70, 45]
country = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
drives_right = [True, False, False, False, True, True, True]

# %%
data = {"cars_per_cap": cars_per_cap, "country": country, "drives_right": drives_right}

# %%
data={"cars_per_cap":cars_per_cap,"country":country,"drives_right":drives_right}

# %%
data_p=pd.DataFrame(data)

# %%
type(data)
# Out:
# dict

# %%
type(data_p)
# Out:
# pandas.core.frame.DataFrame

# %%
data_p
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data_p['cars_per_cap'].plot(kind='hist', bins=20, title='cars_per_cap')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# data_p.groupby('country').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# data_p.groupby('drives_right').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data_p['cars_per_cap'].plot(kind='line', figsize=(8, 4), title='cars_per_cap')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['drives_right'].value_counts()
#     for x_label, grp in data_p.groupby('country')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('country')
# _ = plt.ylabel('drives_right')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(data_p['country'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(data_p, x='cars_per_cap', y='country', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(data_p['drives_right'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(data_p, x='cars_per_cap', y='drives_right', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
cars=pd.read_csv('/content/cars (1).csv')

# %%
cars
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %%
cars=pd.read_csv('/content/cars (1).csv',header=None)

# %%
cars
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
cars.columns
# Out:
# Index([0, 1, 2, 3, 4], dtype='int64')

# %%
cars.rpow
# Out:
# <bound method flex_arith_method_FRAME.<locals>.f of        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True>

# %%
cars.columns = ['country code', 'region', 'country', 'cars_per_cap', 'drive_right']

# %%
cars
# Out:
#   country code region        country  cars_per_cap  drive_right
# 0         USCA     US  United States         809.0        False
# 1        ASPAC    AUS      Australia         731.0         True
# 2        ASPAC    JAP          Japan         588.0         True
# 3        ASPAC     IN          India          18.0         True
# 4        ASPAC     RU         Russia         200.0        False
# 5        LATAM    MOR        Morocco          70.0        False
# 6          AFR     EG          Egypt          45.0        False
# 7          EUR    ENG        England           NaN         True

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
cars=pd.read_csv('/content/cars (1).csv',header=None,index_col=0)

# %%
cars
# Out:
#          1              2      3      4
# 0
# USCA    US  United States  809.0  False
# ASPAC  AUS      Australia  731.0   True
# ASPAC  JAP          Japan  588.0   True
# ASPAC   IN          India   18.0   True
# ASPAC   RU         Russia  200.0  False
# LATAM  MOR        Morocco   70.0  False
# AFR     EG          Egypt   45.0  False
# EUR    ENG        England    NaN   True

# %%
cars.columns = ['region', 'country', 'cars_per_cap', 'drive_right']

# %%
cars
# Out:
#       region        country  cars_per_cap  drive_right
# 0
# USCA      US  United States         809.0        False
# ASPAC    AUS      Australia         731.0         True
# ASPAC    JAP          Japan         588.0         True
# ASPAC     IN          India          18.0         True
# ASPAC     RU         Russia         200.0        False
# LATAM    MOR        Morocco          70.0        False
# AFR       EG          Egypt          45.0        False
# EUR      ENG        England           NaN         True

# %%
cars.index.name='country code'

# %%
cars
# Out:
#              region        country  cars_per_cap  drive_right
# country code
# USCA             US  United States         809.0        False
# ASPAC           AUS      Australia         731.0         True
# ASPAC           JAP          Japan         588.0         True
# ASPAC            IN          India          18.0         True
# ASPAC            RU         Russia         200.0        False
# LATAM           MOR        Morocco          70.0        False
# AFR              EG          Egypt          45.0        False
# EUR             ENG        England           NaN         True

# %%
cars.index.name=None

# %%
cars
# Out:
#       region        country  cars_per_cap  drive_right
# USCA      US  United States         809.0        False
# ASPAC    AUS      Australia         731.0         True
# ASPAC    JAP          Japan         588.0         True
# ASPAC     IN          India          18.0         True
# ASPAC     RU         Russia         200.0        False
# LATAM    MOR        Morocco          70.0        False
# AFR       EG          Egypt          45.0        False
# EUR      ENG        England           NaN         True

# %%
#Hierarchical indexing

# %%
cars=pd.read_csv('/content/cars (1).csv',header=None)

# %%
cars
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
cars.columns = ['country code', 'region', 'country', 'cars_per_cap', 'drive_right']

# %%
cars
# Out:
#   country code region        country  cars_per_cap  drive_right
# 0         USCA     US  United States         809.0        False
# 1        ASPAC    AUS      Australia         731.0         True
# 2        ASPAC    JAP          Japan         588.0         True
# 3        ASPAC     IN          India          18.0         True
# 4        ASPAC     RU         Russia         200.0        False
# 5        LATAM    MOR        Morocco          70.0        False
# 6          AFR     EG          Egypt          45.0        False
# 7          EUR    ENG        England           NaN         True

# %%
cars.set_index(['region','country code'],inplace=True)

# %%
cars
# Out:
#                            country  cars_per_cap  drive_right
# region country code
# US     USCA          United States         809.0        False
# AUS    ASPAC             Australia         731.0         True
# JAP    ASPAC                 Japan         588.0         True
# IN     ASPAC                 India          18.0         True
# RU     ASPAC                Russia         200.0        False
# MOR    LATAM               Morocco          70.0        False
# EG     AFR                   Egypt          45.0        False
# ENG    EUR                 England           NaN         True

# %%
cars
# Out:
#                            country  cars_per_cap  drive_right
# region country code
# US     USCA          United States         809.0        False
# AUS    ASPAC             Australia         731.0         True
# JAP    ASPAC                 Japan         588.0         True
# IN     ASPAC                 India          18.0         True
# RU     ASPAC                Russia         200.0        False
# MOR    LATAM               Morocco          70.0        False
# EG     AFR                   Egypt          45.0        False
# ENG    EUR                 England           NaN         True

# %%
cars=pd.read_csv('/content/cars (1).csv',header=None)
cars.columns = ['country code', 'region', 'country', 'cars_per_cap', 'drive_right']

# %%
cars
# Out:
#   country code region        country  cars_per_cap  drive_right
# 0         USCA     US  United States         809.0        False
# 1        ASPAC    AUS      Australia         731.0         True
# 2        ASPAC    JAP          Japan         588.0         True
# 3        ASPAC     IN          India          18.0         True
# 4        ASPAC     RU         Russia         200.0        False
# 5        LATAM    MOR        Morocco          70.0        False
# 6          AFR     EG          Egypt          45.0        False
# 7          EUR    ENG        England           NaN         True

# %%
cars.set_index(['region','country code'])
# Out:
#                            country  cars_per_cap  drive_right
# region country code
# US     USCA          United States         809.0        False
# AUS    ASPAC             Australia         731.0         True
# JAP    ASPAC                 Japan         588.0         True
# IN     ASPAC                 India          18.0         True
# RU     ASPAC                Russia         200.0        False
# MOR    LATAM               Morocco          70.0        False
# EG     AFR                   Egypt          45.0        False
# ENG    EUR                 England           NaN         True

# %%
cars
# Out:
#   country code region        country  cars_per_cap  drive_right
# 0         USCA     US  United States         809.0        False
# 1        ASPAC    AUS      Australia         731.0         True
# 2        ASPAC    JAP          Japan         588.0         True
# 3        ASPAC     IN          India          18.0         True
# 4        ASPAC     RU         Russia         200.0        False
# 5        LATAM    MOR        Morocco          70.0        False
# 6          AFR     EG          Egypt          45.0        False
# 7          EUR    ENG        England           NaN         True

# %%
cars.set_index(['region','country code'],inplace=True)

# %%
cars
# Out:
#                            country  cars_per_cap  drive_right
# region country code
# US     USCA          United States         809.0        False
# AUS    ASPAC             Australia         731.0         True
# JAP    ASPAC                 Japan         588.0         True
# IN     ASPAC                 India          18.0         True
# RU     ASPAC                Russia         200.0        False
# MOR    LATAM               Morocco          70.0        False
# EG     AFR                   Egypt          45.0        False
# ENG    EUR                 England           NaN         True

# %%
cars.to_csv('cars_df.csv')

# %%
pd.read_csv('cars_df.csv')
# Out:
#   region country code        country  cars_per_cap  drive_right
# 0     US         USCA  United States         809.0        False
# 1    AUS        ASPAC      Australia         731.0         True
# 2    JAP        ASPAC          Japan         588.0         True
# 3     IN        ASPAC          India          18.0         True
# 4     RU        ASPAC         Russia         200.0        False
# 5    MOR        LATAM        Morocco          70.0        False
# 6     EG          AFR          Egypt          45.0        False
# 7    ENG          EUR        England           NaN         True

# %%
data
# Out:
# {'cars_per_cap': [809, 731, 588, 18, 200, 70, 45],
#  'country': ['United States',
#   'Australia',
#   'Japan',
#   'India',
#   'Russia',
#   'Morocco',
#   'Egypt'],
#  'drives_right': [True, False, False, False, True, True, True]}

# %%
cars = pd.DataFrame(data)

cars
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <h4 style = "color : Sky blue"> Example - 2 (Reading data from a file)</h4>
#
# ##### Create a Data Frame by importing cars data from cars.csv

# %%
# Read a file using pandas

cars_df = pd.read_csv('cars.csv')

cars_df
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %% [markdown]
# <h4 style = "color : Sky blue"> Example - 3 (Column headers)</h4>
#
# ##### Read file - skip header

# %%
cars_df = pd.read_csv('cars.csv', header=None)

cars_df
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %% [markdown]
# ##### Assign Headers

# %%
# Returns an array of headers

cars_df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
# Rename Headers

cars_df.columns = ['country code', 'region', 'country', 'cars_per_cap', 'drive_right']

# %%
cars_df
# Out:
#   country code region        country  cars_per_cap  drive_right
# 0         USCA     US  United States         809.0        False
# 1        ASPAC    AUS      Australia         731.0         True
# 2        ASPAC    JAP          Japan         588.0         True
# 3        ASPAC     IN          India          18.0         True
# 4        ASPAC     RU         Russia         200.0        False
# 5        LATAM    MOR        Morocco          70.0        False
# 6          AFR     EG          Egypt          45.0        False
# 7          EUR    ENG        England           NaN         True

# %% [markdown]
# <h4 style = "color : Sky blue"> Example - 4 (Row index/names) </h4>
#
# ##### Read file - skip header and assign first column as index.

# %%
# Index is returned by
cars_df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
# Read file and set 1st column as index
cars_df = pd.read_csv("cars.csv", header= None, index_col=0)

# set the column names
cars_df.columns = ['region', 'country', 'cars_per_cap', 'drive_right']
cars_df
# Out:
#       region        country  cars_per_cap  drive_right
# 0
# USCA      US  United States         809.0        False
# ASPAC    AUS      Australia         731.0         True
# ASPAC    JAP          Japan         588.0         True
# ASPAC     IN          India          18.0         True
# ASPAC     RU         Russia         200.0        False
# LATAM    MOR        Morocco          70.0        False
# AFR       EG          Egypt          45.0        False
# EUR      ENG        England           NaN         True

# %%
# Print the new index
cars_df.index
# Out:
# Index(['USCA', 'ASPAC', 'ASPAC', 'ASPAC', 'ASPAC', 'LATAM', 'AFR', 'EUR'], dtype='object', name=0)

# %% [markdown]
# ##### Rename the Index Name

# %%
cars_df.index.name = 'country_code'
cars_df
# Out:
#              region        country  cars_per_cap  drive_right
# country_code
# USCA             US  United States         809.0        False
# ASPAC           AUS      Australia         731.0         True
# ASPAC           JAP          Japan         588.0         True
# ASPAC            IN          India          18.0         True
# ASPAC            RU         Russia         200.0        False
# LATAM           MOR        Morocco          70.0        False
# AFR              EG          Egypt          45.0        False
# EUR             ENG        England           NaN         True

# %% [markdown]
# ##### Delete the index name

# %%
cars_df.index.name = None
cars_df
# Out:
#       region        country  cars_per_cap  drive_right
# USCA      US  United States         809.0        False
# ASPAC    AUS      Australia         731.0         True
# ASPAC    JAP          Japan         588.0         True
# ASPAC     IN          India          18.0         True
# ASPAC     RU         Russia         200.0        False
# LATAM    MOR        Morocco          70.0        False
# AFR       EG          Egypt          45.0        False
# EUR      ENG        England           NaN         True

# %% [markdown]
# ##### Set Hierarchical index

# %%
# Read file and set 1st column as index
cars_df = pd.read_csv("cars.csv", header= None)

# set the column names
cars_df.columns = ['country_code','region','country','cars_per_cap','drives_right']

cars_df.set_index(['region', 'country_code'], inplace=True)

# %%
cars_df
# Out:
#                            country  cars_per_cap  drives_right
# region country_code
# US     USCA          United States         809.0         False
# AUS    ASPAC             Australia         731.0          True
# JAP    ASPAC                 Japan         588.0          True
# IN     ASPAC                 India          18.0          True
# RU     ASPAC                Russia         200.0         False
# MOR    LATAM               Morocco          70.0         False
# EG     AFR                   Egypt          45.0         False
# ENG    EUR                 England           NaN          True

# %% [markdown]
# <h4 style = "color : Sky blue"> Example - 5 (Write Data Frame to file) </h4>
#
# ##### Write cars_df to cars_to_csv.csv

# %%
cars_df.to_csv('cars_to_csv.csv')
